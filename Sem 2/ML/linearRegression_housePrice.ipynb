# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv('/content/drive/MyDrive/ML_csv/house_price.csv')

# %%
df.head()
# Out:
#    Area   Price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
X = df['Area'].values
Y = df['Price'].values

# %%
np.corrcoef(X, Y)
# Out:
# array([[1.        , 0.97899444],
#        [0.97899444, 1.        ]])

# %%
plt.scatter(X, Y, c = 'green', label = 'Data Points')
plt.xlabel('Area')
plt.ylabel('Price')
plt.legend()
plt.show()
