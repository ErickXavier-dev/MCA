# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv('/content/drive/MyDrive/ML_csv/headbrain.csv')

# %%
df.head()
# Out:
#    Gender  Age Range  Head Size(cm^3)  Brain Weight(grams)
# 0       1          1             4512                 1530
# 1       1          1             3738                 1297
# 2       1          1             4261                 1335
# 3       1          1             3777                 1282
# 4       1          1             4177                 1590

# %%
X = df['Head Size(cm^3)'].values
Y = df['Brain Weight(grams)'].values

# %%
np.corrcoef(X,Y)
# Out:
# array([[1.        , 0.79956971],
#        [0.79956971, 1.        ]])

# %%
plt.scatter(X, Y, c = 'green', label = 'Scatter Plot')
plt.xlabel('Head Size in cm^3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()

# %%
mean_x = np.mean(X)
mean_y = np.mean(Y)

n = len(X)

numer = 0
denom = 0

for i in range(n):
    numer += (X[i] - mean_x) * (Y[i] - mean_y)
    denom += (X[i] - mean_x) ** 2
b1 = numer / denom
b0 = mean_y - (b1 * mean_x)

print("Coefficients for regression line: ", b0, b1)
# Out:
# Coefficients for regression line:  325.57342104944223 0.26342933948939945

# %%
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 5.0)

y = b0 + b1 * X

plt.plot(X, y, color = 'red', label = 'Regression Line')
plt.scatter(X, Y, c = 'green', label = 'Scatter Plot')

plt.xlabel('Head Size in cm^3')
plt.ylabel('Brain Weight in grams')
plt.legend()
plt.show()
